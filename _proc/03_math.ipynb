# %% [raw]
# ---
# output-file: math.html
# title: Mathy functions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(factors)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/math.py#L17){target="_blank" style="float:right; font-size:smaller"}
#
# ### factors
#
# >      factors (n)
#
# return set of divisors of a number

# %%
assert factors(20) == {1, 2, 4, 5, 10, 20}

# %%
#| echo: false
#| output: asis
show_doc(lcm)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/math.py#L47){target="_blank" style="float:right; font-size:smaller"}
#
# ### lcm
#
# >      lcm (a)

# %%
#| echo: false
#| output: asis
show_doc(gcd)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/math.py#L30){target="_blank" style="float:right; font-size:smaller"}
#
# ### gcd
#
# >      gcd (a, b)

# %%
assert gcd(12, 8) == 4
assert gcd(12, 4) == 4
assert gcd(12, 12) == 12
assert lcm([4, 6, 7]) == 84

# %%
def power(a, b, M=None):
    # computes a**b. Actually python pow does this with optional third argument
    res = 1
    while b:
        if b % 2 == 1:
            res = (res * a) % M if M else res * a
            print("res", res)
        a *= a
        b //= 2
    return res


power(3, 2)
# Out:
# res 9
# 9

# %%
#| echo: false
#| output: asis
show_doc(crt)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/math.py#L54){target="_blank" style="float:right; font-size:smaller"}
#
# ### crt
#
# >      crt (remainders, moduli)
#
# Chinese remainder theorem

# %%
rests, mods = (
    [0, -27, -37, -45, -54, -56, -66, -68, -81],
    [37, 41, 433, 23, 17, 19, 29, 593, 13],
)
assert crt(rests, mods) == (600691418730595, 1090937521514009)
# Out:
# Returning remainder and modulo. First valid number is the remainder

# %%
assert crt((3, 5, 2), (4, 6, 5)) == (47, 60)
assert crt((1, 0, 1, 3), (4, 3, 5, 7)) == (381, 420)
assert crt((1, 1, 0, 3), (4, 5, 3, 7)) == (381, 420)
# Out:
# Returning remainder and modulo. First valid number is the remainder
# Returning remainder and modulo. First valid number is the remainder
# Returning remainder and modulo. First valid number is the remainder

# %%
lcm([5, 7, 11])
# Out:
# 385

# %%
crt([4, 4, 6], [5, 7, 11])
# Out:
# Returning remainder and modulo. First valid number is the remainder
# (39, 385)

# %%
#| echo: false
#| output: asis
show_doc(mul_inv)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/math.py#L73){target="_blank" style="float:right; font-size:smaller"}
#
# ### mul_inv
#
# >      mul_inv (a, b)

# %%
assert mul_inv(17, 29) == 12
assert mul_inv(40, 7) == 3

# %%
#| echo: false
#| output: asis
show_doc(Segment)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/math.py#L91){target="_blank" style="float:right; font-size:smaller"}
#
# ### Segment
#
# >      Segment (array, func)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
array = [1, 2, 3, 0, 10, 100, 5, 5]
s = Segment(array, min)

# %%
s.data
# Out:
# [0, 0, 0, 5, 1, 0, 10, 5, 1, 2, 3, 0, 10, 100, 5, 5]

# %%
s.update(7, 2)
s.data
# Out:
# [0, 0, 0, 2, 1, 0, 10, 2, 1, 2, 3, 0, 10, 100, 5, 2]

# %%
def lis(nums, increase=True):
    """
    Computes the length of the longest in(de)creasing subsequence
    Implements https://en.wikipedia.org/wiki/Longest_increasing_subsequence
    I don't include it in the module since it's more complex than the next implementation
    although it has a better time complexity
    """
    previousidx = [-1] * len(nums)
    currentidx = []
    current = []

    for i, num in enumerate(nums):
        idx = bisect_left(current, num)
        previousidx[i] = currentidx[idx - 1] if idx else -1
        if idx == len(current):
            current.append(num)
            currentidx.append(i)
        else:
            current[idx] = num
            currentidx[idx] = i
        print(current, currentidx, previousidx)
    
    idxs = [currentidx[-1]]
    while previousidx[idxs[-1]] != -1:
        idxs.append(previousidx[idxs[-1]])
    return list(reversed([nums[idx] for idx in idxs]))

nums = [2, 8, 9, 5, 6, 7, 1]
lis(nums)
# Out:
# [2] [0] [-1, -1, -1, -1, -1, -1, -1]
# [2, 8] [0, 1] [-1, 0, -1, -1, -1, -1, -1]
# [2, 8, 9] [0, 1, 2] [-1, 0, 1, -1, -1, -1, -1]
# [2, 5, 9] [0, 3, 2] [-1, 0, 1, 0, -1, -1, -1]
# [2, 5, 6] [0, 3, 4] [-1, 0, 1, 0, 3, -1, -1]
# [2, 5, 6, 7] [0, 3, 4, 5] [-1, 0, 1, 0, 3, 4, -1]
# [1, 5, 6, 7] [6, 3, 4, 5] [-1, 0, 1, 0, 3, 4, -1]
# [2, 5, 6, 7]

# %%
#| echo: false
#| output: asis
show_doc(lis)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/math.py#L125){target="_blank" style="float:right; font-size:smaller"}
#
# ### lis
#
# >      lis (nums, func=<built-in function ge>)
#
# Change the func to change it into longest decreasing subsequence. Or other
# Default is operator.ge, which represents longest strictly increasing subsequence

# %%
#| echo: false
#| output: asis
show_doc(angle)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/math.py#L151){target="_blank" style="float:right; font-size:smaller"}
#
# ### angle
#
# >      angle (a, b)

# %%
a = (1,1)
b = (2,-1)
angle(a,b)
# Out:
# 153.434948822922

# %%
nums = [2, 8, 9, 5,5, 6, 7, 1]
lis(nums, operator.ge)
# Out:
# [2, 5, 5, 6, 7]

# %%
#| echo: false
#| output: asis
show_doc(all_combinations)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/math.py#L160){target="_blank" style="float:right; font-size:smaller"}
#
# ### all_combinations
#
# >      all_combinations (it, start=None, end=None)
#
# Returns all combinations from start to end (inclusive).
# Defaults to 1, len(end)

# %%
list(all_combinations([1,2,3],1,3))
# Out:
# [(1,), (2,), (3,), (1, 2), (1, 3), (2, 3), (1, 2, 3)]

# %%
#| echo: false
#| output: asis
show_doc(all_permutations)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/math.py#L175){target="_blank" style="float:right; font-size:smaller"}
#
# ### all_permutations
#
# >      all_permutations (it, start=None, end=None)

# %%
assert list(all_combinations(range(4),2,3)) == [(0, 1),
 (0, 2),
 (0, 3),
 (1, 2),
 (1, 3),
 (2, 3),
 (0, 1, 2),
 (0, 1, 3),
 (0, 2, 3),
 (1, 2, 3)]

# %%
#| echo: false
#| output: asis
show_doc(mst)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/math.py#L186){target="_blank" style="float:right; font-size:smaller"}
#
# ### mst
#
# >      mst (edges)

# %%
edges = [(1, 2, 3), (1, 3, 5), (2, 3, 1), (0, 1, 10)]
assert mst(edges) == 14
