# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Common
#
# > Functions that you can use quite often

# %%
from functools import partial
import functools
from types import FunctionType

# %%
#| echo: false
#| output: asis
show_doc(patch)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/common.py#L38){target="_blank" style="float:right; font-size:smaller"}
#
# ### patch
#
# >      patch (f)
#
# *Decorator: add `f` to the first parameter's class (based on f's type annotations)*

# %%
#| echo: false
#| output: asis
show_doc(patch_to)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/common.py#L25){target="_blank" style="float:right; font-size:smaller"}
#
# ### patch_to
#
# >      patch_to (cls, as_prop=False)
#
# *Decorator: add `f` to `cls`*

# %%
#| echo: false
#| output: asis
show_doc(copy_func)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/common.py#L18){target="_blank" style="float:right; font-size:smaller"}
#
# ### copy_func
#
# >      copy_func (f)
#
# *Copy a non-builtin function (NB `copy.copy` does not work for this)*

# %%
class Test():
    def __init__(self):
        pass

# %%
@patch_to(Test)
def hi(self):
    print('hi there')
Test().hi()
# Out:
# hi there

# %%
#| echo: false
#| output: asis
show_doc(to_int)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/common.py#L44){target="_blank" style="float:right; font-size:smaller"}
#
# ### to_int
#
# >      to_int (it:collections.abc.Iterable, intonly=False)
#
# *Returns contents of iterable converted to int if possible*
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | it | Iterable |  | watch out because passing a string '12t' will be ripped into a list [1,2,t] |
# | intonly | bool | False | removes non-ints if set to True |

# %%
assert to_int(["12",2,'a']) == [12, 2, 'a']
assert to_int(["12",2,'a'], intonly=True) == [12, 2]
assert to_int([[[1],[-2,3]],[4,5,6]]) == [[[1], [-2, 3]], [4, 5, 6]]
assert to_int('bla 202') == ['bla', 202]
assert to_int(None) == []
assert to_int('') == []
assert to_int([]) == []
# Out:
# watch out string will be converted into list with string.split()
# empty line, returning []
# empty line, returning []
# empty line, returning []

# %%
#| echo: false
#| output: asis
show_doc(ints)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/common.py#L78){target="_blank" style="float:right; font-size:smaller"}
#
# ### ints
#
# >      ints (text:str, tolist=False)
#
# *Return a tuple of all the integers in a string, discards everything else*

# %%
assert ints('blabla202test-20') == (202,-20)
assert ints('blabla202test-20', tolist=True) == [202,-20]

# %%
#| echo: false
#| output: asis
show_doc(flatten)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/common.py#L85){target="_blank" style="float:right; font-size:smaller"}
#
# ### flatten
#
# >      flatten (x:collections.abc.Iterable)

# %%
assert flatten([1,2,4,[99,33,[22,11]], 'f']) == [1, 2, 4, 99, 33, 22, 11, 'f']
assert flatten([[[1],[2,3]],[4,5,6]]) == [1, 2, 3, 4, 5, 6]

# %%
#| echo: false
#| output: asis
show_doc(zippify)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/common.py#L100){target="_blank" style="float:right; font-size:smaller"}
#
# ### zippify
#
# >      zippify (iterable, len=2, cat=False)
#
# *Zips an iterable with arbitrary length pieces
#
# e.g. to create a moving window with len n
#
# Example:
# zippify('abcd',2, cat=False)
# --> [('a', 'b'), ('b', 'c'), ('c', 'd')]
#
# If cat = True, joins the moving windows together
# zippify('abcd',2, cat=True)
# --> ['ab', 'bc', 'cd']*

# %%
assert zippify('abcd',2, cat=True) == ['ab', 'bc', 'cd']
assert zippify('abcd',2, cat=False) == [('a', 'b'), ('b', 'c'), ('c', 'd')]
assert zippify('abcde',3) == [('a', 'b', 'c'), ('b', 'c', 'd'), ('c', 'd', 'e')]

# %%
zippify(list('abcdef'),3), zippify(list('abcdef'),3,cat=True)
# Out:
# ([('a', 'b', 'c'), ('b', 'c', 'd'), ('c', 'd', 'e'), ('d', 'e', 'f')],
#  ['abc', 'bcd', 'cde', 'def'])

# %%
#| echo: false
#| output: asis
show_doc(multidict)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/common.py#L119){target="_blank" style="float:right; font-size:smaller"}
#
# ### multidict
#
# >      multidict (items:collections.abc.Iterable[tuple], both=False)
#
# *Given (key, val) pairs, return {key: [val, ....], ...}.*

# %%
tuples = [(2, 'a'),(2, 'b'),(4, 'a')]
dict(tuples), multidict(tuples)
# Out:
# ({2: 'b', 4: 'a'}, defaultdict(list, {2: ['a', 'b'], 4: ['a']}))

# %%
#| echo: false
#| output: asis
show_doc(rev)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/common.py#L129){target="_blank" style="float:right; font-size:smaller"}
#
# ### rev
#
# >      rev (d:dict)
#
# *Reverses keys and values. Make sure the value is hashable*

# %%
a = {(0,0):'f'}
a |= rev(a)
assert a == {(0, 0): 'f', 'f': (0, 0)}

# %% [markdown]
# ## Peter Norvig AoC helper functions
#
# > All of these are taken from github of Peter Norvig
# > https://github.com/norvig/pytudes/blob/master/ipynb/Advent-2020.ipynb

# %%
#| echo: false
#| output: asis
show_doc(data)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/common.py#L134){target="_blank" style="float:right; font-size:smaller"}
#
# ### data
#
# >      data (filename='input', parser=<class 'str'>, sep='\n')
#
# *Split the day's input file into sections separated by `sep`, and apply `parser` to each.*

# %%
#| echo: false
#| output: asis
show_doc(quantify)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/common.py#L140){target="_blank" style="float:right; font-size:smaller"}
#
# ### quantify
#
# >      quantify (iterable, pred=<class 'bool'>)
#
# *Count the number of items in iterable for which pred is true.*

# %%
assert quantify(['a','11',11,22], pred=lambda x: isinstance(x, int)) == 2
assert quantify([1,2,3,4,5,6,7], lambda x: x==5) == 1
assert quantify([1,2,3,4], lambda x: x<3) == 2

# %%
#| echo: false
#| output: asis
show_doc(atom)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/common.py#L145){target="_blank" style="float:right; font-size:smaller"}
#
# ### atom
#
# >      atom (text:str)
#
# *Parse text into a single float or int or str.*

# %%
atom('11') == 11
# Out:
# True

# %%
#| echo: false
#| output: asis
show_doc(atoms)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/common.py#L155){target="_blank" style="float:right; font-size:smaller"}
#
# ### atoms
#
# >      atoms (text:str, ignore='', sep=None)
#
# *Parse text into atoms (numbers or strs), possibly ignoring a regex.*

# %%
atoms('abc 111 def')
# Out:
# ('abc', 111, 'def')

# %%
#| echo: false
#| output: asis
show_doc(list_atoms)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/common.py#L163){target="_blank" style="float:right; font-size:smaller"}
#
# ### list_atoms
#
# >      list_atoms (inp:list)

# %%
assert list_atoms(['1', '3.2', 'a', 1])

# %%
#| echo: false
#| output: asis
show_doc(list_multiply)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/common.py#L168){target="_blank" style="float:right; font-size:smaller"}
#
# ### list_multiply
#
# >      list_multiply (a:collections.abc.Iterable, b:collections.abc.Iterable)
#
# *Multiplies two iterables elementwise
#
# list_multiply([1,2,3],[2,3,4]) -> [2, 6, 12]*

# %%
assert list_multiply([1,2,3],[2,3,4]) == [2, 6, 12]
assert list_multiply((1,2,3),(2,3,4)) == [2, 6, 12]
assert list_multiply([1,2,3],(2,3,4)) == [2, 6, 12]

# %%
#| echo: false
#| output: asis
show_doc(mapt)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/common.py#L178){target="_blank" style="float:right; font-size:smaller"}
#
# ### mapt
#
# >      mapt (fn, *args)
#
# *map(fn, *args) and return the result as a tuple.*
