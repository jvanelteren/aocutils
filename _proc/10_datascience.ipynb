# %% [raw]
# ---
# description: A collection of somewhat handy functions to make your AoC puzzle life
#   solving a bit easier
# output-file: datascience.html
# title: Data science helpers
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(untar_data)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/datascience.py#L23){target="_blank" style="float:right; font-size:smaller"}
#
# ### untar_data
#
# >      untar_data (path, save_dir=None)

# %%
#| echo: false
#| output: asis
show_doc(timeit)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/datascience.py#L38){target="_blank" style="float:right; font-size:smaller"}
#
# ### timeit
#
# >      timeit (description=None)

# %%
#| echo: false
#| output: asis
show_doc(save)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/datascience.py#L52){target="_blank" style="float:right; font-size:smaller"}
#
# ### save
#
# >      save (data, filename)

# %%
#| echo: false
#| output: asis
show_doc(load)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/datascience.py#L48){target="_blank" style="float:right; font-size:smaller"}
#
# ### load
#
# >      load (filename)

# %%
#| echo: false
#| output: asis
show_doc(nan_inspect)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/datascience.py#L57){target="_blank" style="float:right; font-size:smaller"}
#
# ### nan_inspect
#
# >      nan_inspect (df)
