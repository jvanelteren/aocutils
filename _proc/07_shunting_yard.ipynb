# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#|output: asis
#| echo: false
show_doc(ShuntingYard)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/shunting.py#L23){target="_blank" style="float:right; font-size:smaller"}
#
# ### ShuntingYard
#
# >      ShuntingYard (prec=None, ops=None)
#
# Init with a precedence dictionary. Then call SY.calc(line), with a string as input
#
# Example precedence dictionary. Higher numbers have a higher precedence:
# prec = defaultdict(lambda: int(9))
# prec.update({'*':4,
#         '+':4,
#         '/':4,
#         ':':4,
#         '-':4,
#         '^':4,
#         '**':4})
#
# self.ops is a dictionary with the functions that are called with certain symbols, e.g.
# Example self.ops:
# self.ops = {
#         '+' : operator.add,
#         '-' : operator.sub,
#         '*' : operator.mul,
#         '/' : operator.truediv,
#         ':' : operator.truediv,
#         '%' : operator.mod,
#         '^' : operator.xor,
#         '**' : pow,
#     }

# %%
# prec = {'*':4, '+':5}

# SY = ShuntingYard(prec)
# f = open('input.txt')
# lines = [line.rstrip('\n') for line in f]
# ans = 0
# for line in lines:
#     ans += SY.calc(line)
# ans
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\GEBRUI~1\AppData\Local\Temp/ipykernel_7528/2602260679.py in <module>
#       2
#       3 SY = ShuntingYard(prec)
# ----> 4 f = open('input.txt')
#       5 lines = [line.rstrip('\n') for line in f]
#       6 ans = 0
#
# FileNotFoundError: [Errno 2] No such file or directory: 'input.txt'
