# %% [raw]
# ---
# output-file: special.html
# title: Specific algo's
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
import sys
for p in sys.path: print(p)
# Out:
# D:\Programmeren\adventofcode\.aocenv\Scripts\nbdev_prepare.exe
# C:\Program Files\Python310\python310.zip
# C:\Program Files\Python310\DLLs
# C:\Program Files\Python310\lib
# C:\Program Files\Python310
# D:\Programmeren\adventofcode\.aocenv
# D:\Programmeren\adventofcode\.aocenv\lib\site-packages
# d:\programmeren\testnbdev
# d:\programmeren\aocutils
# D:\Programmeren\adventofcode\.aocenv\lib\site-packages\win32
# D:\Programmeren\adventofcode\.aocenv\lib\site-packages\win32\lib
# D:\Programmeren\adventofcode\.aocenv\lib\site-packages\Pythonwin

# %%
#|output: asis
#| echo: false
show_doc(md5)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/special.py#L15){target="_blank" style="float:right; font-size:smaller"}
#
# ### md5
#
# >      md5 (input)

# %%
md5('bla')
# Out:
# '128ecf542a35ac5270a87dc740918404'

# %%
#|output: asis
#| echo: false
show_doc(binarysearch)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/special.py#L19){target="_blank" style="float:right; font-size:smaller"}
#
# ### binarysearch
#
# >      binarysearch (minim, maxim, function, flips_to_true=True, verbose=True)
#
# function needs to return a boolean whether the solution is ok
# this implementation is for function that starts with false for minim and flip to true
# for TTTTFFFF, pass set flips_to_true flag to false. This flag is important to set correct!

# %%
assert binarysearch(0,200, lambda x: x > 50, verbose=False) == 51
assert binarysearch(0,200, lambda x: x < 50, flips_to_true=False, verbose=False) == 49
assert binarysearch(0,201, lambda x: x > 50, verbose=False) == 51
assert binarysearch(0,201, lambda x: x < 50, flips_to_true=False, verbose=False) == 49
assert binarysearch(0,200, lambda x: x >= 50, verbose=False) == 50
assert binarysearch(0,200, lambda x: x <= 50, flips_to_true=False, verbose=False) == 50
assert binarysearch(0,201, lambda x: x >= 50, verbose=False) == 50
assert binarysearch(0,201, lambda x: x <= 50, flips_to_true=False, verbose=False) == 50
# Out:
# solution found 51
# solution found 49
# solution found 51
# solution found 49
# solution found 50
# solution found 50
# solution found 50
# solution found 50

# %%
#|output: asis
#| echo: false
show_doc(deduce_matches)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/special.py#L45){target="_blank" style="float:right; font-size:smaller"}
#
# ### deduce_matches
#
# >      deduce_matches (input_dict, option_type=<class 'str'>)
#
# Takes a dict with multiple keys that have one or more options
# The trick is to start with what you know: keys with one option and remove that option for the other keys
# Continuing that process leads to every key ending up with one option (hopefully)
#
# Assumes: the options are strings and stored in an interable

# %%
meals = {'morning': ['yoghurt', 'lasagna', 'pizza'],
        'lunch': ['sandwich', 'lasagna'],
        'evening': ['pizza', 'lasagna'],
        'night': ['pizza']}
deduce_matches(meals)
# Out:
# {'morning': 'yoghurt',
#  'lunch': 'sandwich',
#  'evening': 'lasagna',
#  'night': 'pizza'}

# %%
#|output: asis
#| echo: false
show_doc(find_pattern_in_iter)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/special.py#L66){target="_blank" style="float:right; font-size:smaller"}
#
# ### find_pattern_in_iter
#
# >      find_pattern_in_iter (start_pattern, function, goal=None,
# >                            n_iter=1000000000)
#
# Returns when a SPECIFIED pattern has been found from a function
# If goal = None, then first time the start pattern shows up again is returned
# Returns steps, pattern

# %%
#|output: asis
#| echo: false
show_doc(find_repeat)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/special.py#L82){target="_blank" style="float:right; font-size:smaller"}
#
# ### find_repeat
#
# >      find_repeat (start_pattern, function, n_iter=None)
#
# Returns when a NONSPECFIED repeating pattern has been found
# Returns steps, pattern

# %%
#|output: asis
#| echo: false
show_doc(find_cycle)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/special.py#L99){target="_blank" style="float:right; font-size:smaller"}
#
# ### find_cycle
#
# >      find_cycle (start_pattern, function)
#
# Find cycle length of some repeating pattern, by first inspecting which item repeats when
# And subtracting the time the item was first seen

# %%
assert find_pattern_in_iter(99,Test_gen(),n_iter=10) == (5,99)
assert find_pattern_in_iter(99,Test_gen(),goal=10, n_iter=10) == (2,10)
assert find_pattern_in_iter(99,Test_gen(),goal=5, n_iter=10) == (1,5)
assert find_repeat(99,Test_gen(),n_iter=10) == (4,5)
# Out:
# found at step 5 99
# found at step 2 10
# found at step 1 5
# found at step 4 5

# %%
#|output: asis
#| echo: false
show_doc(UnionFind)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/special.py#L109){target="_blank" style="float:right; font-size:smaller"}
#
# ### UnionFind
#
# >      UnionFind (it)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
# tested above class on some leetcode problems: works!
uf = UnionFind([100,101,102,103])
uf.union(101,100)
uf.groups()
# Out:
# [[100, 101], [102], [103]]

# %%
#|output: asis
#| echo: false
show_doc(Block)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/special.py#L158){target="_blank" style="float:right; font-size:smaller"}
#
# ### Block
#
# >      Block (left:int, right:int, up:int, leftrange:int, rightrange:int,
# >             uprange:int, lazy:int, val:int, subblocks:list)

# %%
b = Block(0,0,0,100,100,100,0,0,list())
b.add(Block(0,0,0,100,100,100,0,0,list()))
assert b.size() == 1

# %%
b = Block(0,0,0,100,100,100,0,0,list())
b.add(Block(0,0,0,50,50,50,0,0,list()))
assert b.size() == 1
b.subblocks
# Out:
# [Block(left=0, right=0, up=0, leftrange=50, rightrange=50, uprange=50, lazy=1, val=1, subblocks=[]),
#  Block(left=0, right=0, up=51, leftrange=50, rightrange=50, uprange=50, lazy=0, val=0, subblocks=[]),
#  Block(left=0, right=51, up=0, leftrange=50, rightrange=50, uprange=50, lazy=0, val=0, subblocks=[]),
#  Block(left=0, right=51, up=51, leftrange=50, rightrange=50, uprange=50, lazy=0, val=0, subblocks=[]),
#  Block(left=51, right=0, up=0, leftrange=50, rightrange=50, uprange=50, lazy=0, val=0, subblocks=[]),
#  Block(left=51, right=0, up=51, leftrange=50, rightrange=50, uprange=50, lazy=0, val=0, subblocks=[]),
#  Block(left=51, right=51, up=0, leftrange=50, rightrange=50, uprange=50, lazy=0, val=0, subblocks=[]),
#  Block(left=51, right=51, up=51, leftrange=50, rightrange=50, uprange=50, lazy=0, val=0, subblocks=[])]

# %%
b = Block(0,0,0,100,100,100,0,0,list())
b.add(Block(0,0,0,25,25,25,0,0,list()))
b.add(Block(0,0,0,1,1,1,0,0,list()))
b.add(Block(1,1,1,1,1,1,0,0,list()))
b.size(), b.brightest()
# Out:
# (2, 2)

# %%
b.brightest()
# Out:
# 2

# %%
#|output: asis
#| echo: false
show_doc(LazySegmentTree)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/special.py#L221){target="_blank" style="float:right; font-size:smaller"}
#
# ### LazySegmentTree
#
# >      LazySegmentTree (left, right)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
1+1
# Out:
# 2
