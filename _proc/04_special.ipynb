# %% [raw]
# ---
# output-file: special.html
# title: Specific algo's
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(md5)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/special.py#L18){target="_blank" style="float:right; font-size:smaller"}
#
# ### md5
#
# >      md5 (input)

# %%
md5('bla')
# Out:
# '128ecf542a35ac5270a87dc740918404'

# %%
#| echo: false
#| output: asis
show_doc(binarysearch)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/special.py#L22){target="_blank" style="float:right; font-size:smaller"}
#
# ### binarysearch
#
# >      binarysearch (minim, maxim, function, flips_to_true=True, verbose=True)
#
# *function needs to return a boolean whether the solution is ok
# this implementation is for function that starts with false for minim and flip to true
# for TTTTFFFF, pass set flips_to_true flag to false. This flag is important to set correct!*

# %%
assert binarysearch(0,200, lambda x: x > 50, verbose=False) == 51
assert binarysearch(0,200, lambda x: x < 50, flips_to_true=False, verbose=False) == 49
assert binarysearch(0,201, lambda x: x > 50, verbose=False) == 51
assert binarysearch(0,201, lambda x: x < 50, flips_to_true=False, verbose=False) == 49
assert binarysearch(0,200, lambda x: x >= 50, verbose=False) == 50
assert binarysearch(0,200, lambda x: x <= 50, flips_to_true=False, verbose=False) == 50
assert binarysearch(0,201, lambda x: x >= 50, verbose=False) == 50
assert binarysearch(0,201, lambda x: x <= 50, flips_to_true=False, verbose=False) == 50
# Out:
# solution found 51
# solution found 49
# solution found 51
# solution found 49
# solution found 50
# solution found 50
# solution found 50
# solution found 50

# %%
#| echo: false
#| output: asis
show_doc(deduce_matches)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/special.py#L48){target="_blank" style="float:right; font-size:smaller"}
#
# ### deduce_matches
#
# >      deduce_matches (input_dict)
#
# *Takes a dict with multiple keys that have one or more options
# The trick is to start with what you know: keys with one option and remove that option for the other keys
# Continuing that process leads to every key ending up with one option (hopefully)*

# %%
meals = {'morning': ['yoghurt', 'lasagna', 'pizza'],
        'lunch': ['sandwich', 'lasagna'],
        'evening': ['pizza', 'lasagna'],
        'night': ['pizza']}

answer = {'morning': 'yoghurt',
 'lunch': 'sandwich',
 'evening': 'lasagna',
 'night': 'pizza'}
assert deduce_matches(meals) == answer

# now test with tuples instead of strings as option
meals = {'morning': [('yoghurt',), ('lasagna',),('pizza',)],
        'lunch': [('sandwich',), ('lasagna',)],
        'evening': [('pizza',), ('lasagna',)],
        'night': [('pizza',)]}
assert deduce_matches(meals) == {k: tuple([v,]) for k, v in answer.items()}

# %%
#| echo: false
#| output: asis
show_doc(find_specific_pattern)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/special.py#L73){target="_blank" style="float:right; font-size:smaller"}
#
# ### find_specific_pattern
#
# >      find_specific_pattern (start_pattern, function, goal=None,
# >                             n_iter=1000000000)
#
# *Returns when a SPECIFIED pattern has been found from a function
# If goal = None, then first time the start pattern shows up again is returned
# Returns steps, pattern*

# %%
#| echo: false
#| output: asis
show_doc(find_repeat)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/special.py#L89){target="_blank" style="float:right; font-size:smaller"}
#
# ### find_repeat
#
# >      find_repeat (start_pattern, function, n_iter=None)
#
# *Returns when a NONSPECFIED repeating pattern has been found
# Returns steps, pattern*

# %%
#| echo: false
#| output: asis
show_doc(find_cycle)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/special.py#L106){target="_blank" style="float:right; font-size:smaller"}
#
# ### find_cycle
#
# >      find_cycle (start_pattern, function)
#
# *Find cycle length of some repeating pattern, by first inspecting which item repeats when
# And subtracting the time the item was first seen*

# %%
assert find_specific_pattern(99,Test_gen()) == 5
assert find_specific_pattern(99,Test_gen(),goal=10) == 2
assert find_specific_pattern(99,Test_gen(),goal=5) == 1
# Out:
# At step 5, goal: 99 was found
# At step 2, goal: 10 was found
# At step 1, goal: 5 was found

# %%
assert find_repeat(-1,lambda x: (x+1) % 7) == (8,0)
# Out:
# Repeat was found at step 8. Pattern: 0 returning steps, pattern

# %%
#| echo: false
#| output: asis
show_doc(UnionFind)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/special.py#L116){target="_blank" style="float:right; font-size:smaller"}
#
# ### UnionFind
#
# >      UnionFind (it)
#
# *Initialize self.  See help(type(self)) for accurate signature.*

# %%
# tested above class on some leetcode problems: works!
uf = UnionFind([100,101,102,103])
uf.union(101,100)
uf.groups()
# Out:
# [[100, 101], [102], [103]]

# %%
#| echo: false
#| output: asis
show_doc(Octree)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/special.py#L168){target="_blank" style="float:right; font-size:smaller"}
#
# ### Octree
#
# >      Octree (left:int, right:int, up:int, leftrange:int, rightrange:int,
# >              uprange:int, totalhits:int=0)

# %%
Robot = namedtuple('Robot', 'l r u p')
lines=open('recursivepartition.txt').read().splitlines()
maxx = 0
robots =[Robot(*ints(line)) for line in lines]
maxx = max(max(r.r, r.l, r.u) + r.p for r in robots)
size = 2
while size < maxx:
    size *= 2

b = Octree(0,0,0,size,size,size)
b.count(robots)
queue = [b]

while queue:
    cur = heapq.heappop(queue)
    if cur.leftrange == 0:
        break
    else:
        for b in cur.split():
            b.count(robots)
            heapq.heappush(queue, b)
assert cur.distance == 121493971

# %%
#| echo: false
#| output: asis
show_doc(LazySegmentTree)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/special.py#L207){target="_blank" style="float:right; font-size:smaller"}
#
# ### LazySegmentTree
#
# >      LazySegmentTree (left, right)
#
# *Initialize self.  See help(type(self)) for accurate signature.*

# %%
l = LazySegmentTree(0,100)
l.add(0,50)
l.add(0,50)
l.add(49,51)
l.add(51,51)
assert l.getbest() == 3

# %%
#| echo: false
#| output: asis
show_doc(Trie)
# Out:
# ---
#
# [source](https://github.com/jvanelteren/aocutils/blob/master/aocutils/special.py#L236){target="_blank" style="float:right; font-size:smaller"}
#
# ### Trie
#
# >      Trie ()
